# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.   
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kabalo
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 1 | marawi
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | havelock
# Processing Record 7 of Set 1 | tuatapere
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | teknaf
# Processing Record 10 of Set 1 | severo-yeniseyskiy
# Processing Record 11 of Set 1 | kruisfontein
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | pietrosani
# Processing Record 14 of Set 1 | san quintin
# Processing Record 15 of Set 1 | lucapa
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | sikonge
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | salalah
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | chernyshevsk
# Processing Record 24 of Set 1 | qaqortoq
# Processing Record 25 of Set 1 | majene
# Processing Record 26 of Set 1 | san cristobal
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | bubaque
# Processing Record 30 of Set 1 | yumen
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | puri
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | maswa
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | dikson
# Processing Record 41 of Set 1 | faanui
# Processing Record 42 of Set 1 | geraldton
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | lavrentiya
# Processing Record 45 of Set 1 | vao
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | conceicao do araguaia
# Processing Record 48 of Set 1 | waingapu
# Processing Record 49 of Set 1 | komsomolskiy
# Processing Record 50 of Set 1 | san javier
# Processing Record 1 of Set 2 | takoradi
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | dicabisagan
# Processing Record 4 of Set 2 | talnakh
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 2 | garowe
# Processing Record 8 of Set 2 | yoichi
# Processing Record 9 of Set 2 | sorong
# Processing Record 10 of Set 2 | ilulissat
# Processing Record 11 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 2 | pisco
# Processing Record 14 of Set 2 | ponta delgada
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | sadove
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | aracati
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 2 | chapais
# Processing Record 22 of Set 2 | katherine
# Processing Record 23 of Set 2 | kodiak
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | apollonia
# Processing Record 26 of Set 2 | laguna
# Processing Record 27 of Set 2 | palana
# Processing Record 28 of Set 2 | francisco beltrao
# Processing Record 29 of Set 2 | ancud
# Processing Record 30 of Set 2 | paamiut
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | kenai
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | okakarara
# Processing Record 35 of Set 2 | bonthe
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | new norfolk
# Processing Record 38 of Set 2 | linxia
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | nikki
# Processing Record 43 of Set 2 | qaanaaq
# Processing Record 44 of Set 2 | krasnoshchekovo
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | santa rosa
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | kaitangata
# Processing Record 1 of Set 3 | miram shah
# Processing Record 2 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 3 | vanimo
# Processing Record 4 of Set 3 | talaya
# Processing Record 5 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 3 | sept-iles
# Processing Record 7 of Set 3 | morondava
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | fortuna
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 3 | yar-sale
# Processing Record 16 of Set 3 | khani
# Processing Record 17 of Set 3 | deoria
# Processing Record 18 of Set 3 | la paz
# Processing Record 19 of Set 3 | kaeo
# Processing Record 20 of Set 3 | progreso
# Processing Record 21 of Set 3 | coromandel
# Processing Record 22 of Set 3 | biak
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | hit
# Processing Record 25 of Set 3 | thompson
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | antofagasta
# Processing Record 28 of Set 3 | pascagoula
# Processing Record 29 of Set 3 | cotonou
# Processing Record 30 of Set 3 | cockburn town
# Processing Record 31 of Set 3 | asau
# Processing Record 32 of Set 3 | ilheus
# Processing Record 33 of Set 3 | cabo san lucas
# Processing Record 34 of Set 3 | hazorasp
# Processing Record 35 of Set 3 | ballina
# Processing Record 36 of Set 3 | sarkand
# Processing Record 37 of Set 3 | atar
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | kamaishi
# Processing Record 41 of Set 3 | naze
# Processing Record 42 of Set 3 | regina
# Processing Record 43 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 3 | munoz
# Processing Record 45 of Set 3 | bilibino
# Processing Record 46 of Set 3 | port hardy
# Processing Record 47 of Set 3 | broken hill
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | hamilton
# Processing Record 50 of Set 3 | havoysund
# Processing Record 1 of Set 4 | petrozavodsk
# Processing Record 2 of Set 4 | raciborz
# Processing Record 3 of Set 4 | durant
# Processing Record 4 of Set 4 | prince george
# Processing Record 5 of Set 4 | port lincoln
# Processing Record 6 of Set 4 | lundazi
# Processing Record 7 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 8 of Set 4 | kedrovyy
# Processing Record 9 of Set 4 | saposoa
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | lasa
# Processing Record 13 of Set 4 | bluff
# Processing Record 14 of Set 4 | kholmogory
# Processing Record 15 of Set 4 | severo-kurilsk
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | atambua
# Processing Record 18 of Set 4 | herat
# Processing Record 19 of Set 4 | south houston
# Processing Record 20 of Set 4 | atuona
# Processing Record 21 of Set 4 | oneonta
# Processing Record 22 of Set 4 | vanderhoof
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | luderitz
# Processing Record 27 of Set 4 | baijiantan
# Processing Record 28 of Set 4 | yantzaza
# Processing Record 29 of Set 4 | bababe
# City not found. Skipping...
# Processing Record 30 of Set 4 | san pedro
# Processing Record 31 of Set 4 | price
# Processing Record 32 of Set 4 | misratah
# Processing Record 33 of Set 4 | kutum
# Processing Record 34 of Set 4 | vastervik
# City not found. Skipping...
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | tezu
# Processing Record 37 of Set 4 | oksovskiy
# Processing Record 38 of Set 4 | savannah bight
# Processing Record 39 of Set 4 | nikolskoye
# Processing Record 40 of Set 4 | haripur
# Processing Record 41 of Set 4 | terrace bay
# Processing Record 42 of Set 4 | nuuk
# Processing Record 43 of Set 4 | acapulco
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | kapaa
# Processing Record 46 of Set 4 | longyearbyen
# Processing Record 47 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 48 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 49 of Set 4 | santa maria del oro
# Processing Record 50 of Set 4 | port moresby
# Processing Record 1 of Set 5 | grindavik
# Processing Record 2 of Set 5 | pundaguitan
# Processing Record 3 of Set 5 | srednekolymsk
# Processing Record 4 of Set 5 | lalibela
# Processing Record 5 of Set 5 | kosh-agach
# Processing Record 6 of Set 5 | thornbury
# Processing Record 7 of Set 5 | thanh hoa
# Processing Record 8 of Set 5 | along
# Processing Record 9 of Set 5 | yerofey pavlovich
# Processing Record 10 of Set 5 | nosy varika
# Processing Record 11 of Set 5 | saldanha
# Processing Record 12 of Set 5 | malinyi
# Processing Record 13 of Set 5 | hermiston
# Processing Record 14 of Set 5 | chardara
# Processing Record 15 of Set 5 | bay roberts
# Processing Record 16 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 5 | effingham
# Processing Record 18 of Set 5 | biloela
# Processing Record 19 of Set 5 | sorland
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | coos bay
# Processing Record 22 of Set 5 | hirara
# Processing Record 23 of Set 5 | malmesbury
# Processing Record 24 of Set 5 | hithadhoo
# Processing Record 25 of Set 5 | hakkari
# Processing Record 26 of Set 5 | conceicao do almeida
# Processing Record 27 of Set 5 | vila velha
# Processing Record 28 of Set 5 | ponta do sol
# Processing Record 29 of Set 5 | salisbury
# Processing Record 30 of Set 5 | farafangana
# Processing Record 31 of Set 5 | adrar
# Processing Record 32 of Set 5 | westerland
# Processing Record 33 of Set 5 | olean
# Processing Record 34 of Set 5 | kazerun
# Processing Record 35 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 5 | westport
# Processing Record 37 of Set 5 | raudeberg
# Processing Record 38 of Set 5 | provideniya
# Processing Record 39 of Set 5 | vagay
# Processing Record 40 of Set 5 | kununurra
# Processing Record 41 of Set 5 | xico
# Processing Record 42 of Set 5 | mount gambier
# Processing Record 43 of Set 5 | omboue
# Processing Record 44 of Set 5 | bhatkal
# Processing Record 45 of Set 5 | nioro
# Processing Record 46 of Set 5 | mayumba
# Processing Record 47 of Set 5 | demba
# Processing Record 48 of Set 5 | yablonovo
# Processing Record 49 of Set 5 | shingu
# Processing Record 50 of Set 5 | east london
# Processing Record 1 of Set 6 | manaus
# Processing Record 2 of Set 6 | kuusamo
# Processing Record 3 of Set 6 | platanos
# Processing Record 4 of Set 6 | basco
# Processing Record 5 of Set 6 | bulgan
# Processing Record 6 of Set 6 | chokurdakh
# Processing Record 7 of Set 6 | husavik
# Processing Record 8 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | deputatskiy
# Processing Record 11 of Set 6 | zamardi
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | mackay
# Processing Record 14 of Set 6 | whitianga
# Processing Record 15 of Set 6 | itarema
# Processing Record 16 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 17 of Set 6 | ketchikan
# Processing Record 18 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 6 | yanam
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | zyryanka
# Processing Record 22 of Set 6 | richards bay
# Processing Record 23 of Set 6 | miri
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | kieta
# Processing Record 26 of Set 6 | upernavik
# Processing Record 27 of Set 6 | iguape
# Processing Record 28 of Set 6 | rodrigues alves
# Processing Record 29 of Set 6 | zhigansk
# Processing Record 30 of Set 6 | baykit
# Processing Record 31 of Set 6 | dukat
# Processing Record 32 of Set 6 | namibe
# Processing Record 33 of Set 6 | rovaniemi
# Processing Record 34 of Set 6 | saint-augustin
# Processing Record 35 of Set 6 | cap malheureux
# Processing Record 36 of Set 6 | brae
# Processing Record 37 of Set 6 | magadan
# Processing Record 38 of Set 6 | lagos
# Processing Record 39 of Set 6 | coihaique
# Processing Record 40 of Set 6 | dingle
# Processing Record 41 of Set 6 | ouesso
# Processing Record 42 of Set 6 | ullapool
# Processing Record 43 of Set 6 | nakhon sawan
# Processing Record 44 of Set 6 | hanumangarh
# Processing Record 45 of Set 6 | chuy
# Processing Record 46 of Set 6 | vilhena
# Processing Record 47 of Set 6 | chakia
# Processing Record 48 of Set 6 | chilliwack
# Processing Record 49 of Set 6 | port blair
# Processing Record 50 of Set 6 | tarakan
# Processing Record 1 of Set 7 | krasnoselkup
# Processing Record 2 of Set 7 | sobolevo
# Processing Record 3 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 7 | cabedelo
# Processing Record 5 of Set 7 | qingan
# City not found. Skipping...
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | kibala
# Processing Record 8 of Set 7 | puerto maldonado
# Processing Record 9 of Set 7 | biltine
# Processing Record 10 of Set 7 | riyadh
# Processing Record 11 of Set 7 | burica
# City not found. Skipping...
# Processing Record 12 of Set 7 | trincomalee
# Processing Record 13 of Set 7 | lulea
# Processing Record 14 of Set 7 | sarai
# Processing Record 15 of Set 7 | rocha
# Processing Record 16 of Set 7 | georgetown
# Processing Record 17 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | aden
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | pombia
# Processing Record 21 of Set 7 | misasi
# Processing Record 22 of Set 7 | karlstad
# Processing Record 23 of Set 7 | inhambane
# Processing Record 24 of Set 7 | moron
# Processing Record 25 of Set 7 | portree
# Processing Record 26 of Set 7 | cabiraoan
# Processing Record 27 of Set 7 | phan thiet
# Processing Record 28 of Set 7 | znamenskoye
# Processing Record 29 of Set 7 | lorengau
# Processing Record 30 of Set 7 | russell
# Processing Record 31 of Set 7 | lipki
# Processing Record 32 of Set 7 | senno
# Processing Record 33 of Set 7 | buala
# Processing Record 34 of Set 7 | nizwa
# Processing Record 35 of Set 7 | siniscola
# Processing Record 36 of Set 7 | port elizabeth
# Processing Record 37 of Set 7 | namatanai
# Processing Record 38 of Set 7 | fairbanks
# Processing Record 39 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 40 of Set 7 | kushmurun
# Processing Record 41 of Set 7 | pangnirtung
# Processing Record 42 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 7 | qui nhon
# Processing Record 44 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 45 of Set 7 | gaoua
# Processing Record 46 of Set 7 | krivodol
# Processing Record 47 of Set 7 | altay
# Processing Record 48 of Set 7 | sakakah
# Processing Record 49 of Set 7 | paita
# Processing Record 50 of Set 7 | olafsvik
# Processing Record 1 of Set 8 | skelleftea
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | rio grande
# Processing Record 4 of Set 8 | haines junction
# Processing Record 5 of Set 8 | kloulklubed
# Processing Record 6 of Set 8 | maputo
# Processing Record 7 of Set 8 | quimperle
# Processing Record 8 of Set 8 | keetmanshoop
# Processing Record 9 of Set 8 | sola
# Processing Record 10 of Set 8 | sandomierz
# Processing Record 11 of Set 8 | prado
# Processing Record 12 of Set 8 | luanda
# Processing Record 13 of Set 8 | cordoba
# Processing Record 14 of Set 8 | sale
# Processing Record 15 of Set 8 | college
# Processing Record 16 of Set 8 | gizo
# Processing Record 17 of Set 8 | hofn
# Processing Record 18 of Set 8 | wangqing
# Processing Record 19 of Set 8 | hambantota
# Processing Record 20 of Set 8 | boende
# Processing Record 21 of Set 8 | vostok
# Processing Record 22 of Set 8 | cayenne
# Processing Record 23 of Set 8 | rafai
# Processing Record 24 of Set 8 | torbay
# Processing Record 25 of Set 8 | sabha
# Processing Record 26 of Set 8 | saint-philippe
# Processing Record 27 of Set 8 | liberty
# Processing Record 28 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 29 of Set 8 | souillac
# Processing Record 30 of Set 8 | mamakan
# Processing Record 31 of Set 8 | shubarshi
# Processing Record 32 of Set 8 | velke mezirici
# Processing Record 33 of Set 8 | mahebourg
# Processing Record 34 of Set 8 | bambanglipuro
# Processing Record 35 of Set 8 | kavaratti
# Processing Record 36 of Set 8 | sabzevar
# Processing Record 37 of Set 8 | tamandare
# Processing Record 38 of Set 8 | thunder bay
# Processing Record 39 of Set 8 | taoudenni
# Processing Record 40 of Set 8 | meulaboh
# Processing Record 41 of Set 8 | tukrah
# Processing Record 42 of Set 8 | ferlach
# Processing Record 43 of Set 8 | necochea
# Processing Record 44 of Set 8 | santa catalina
# Processing Record 45 of Set 8 | duluth
# Processing Record 46 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 8 | port-gentil
# Processing Record 48 of Set 8 | gari
# Processing Record 49 of Set 8 | chiungutwa
# Processing Record 50 of Set 8 | iqaluit
# Processing Record 1 of Set 9 | puqi
# Processing Record 2 of Set 9 | lagoa
# Processing Record 3 of Set 9 | charters towers
# Processing Record 4 of Set 9 | marsh harbour
# Processing Record 5 of Set 9 | traverse city
# Processing Record 6 of Set 9 | birin
# Processing Record 7 of Set 9 | encruzilhada do sul
# Processing Record 8 of Set 9 | ossora
# Processing Record 9 of Set 9 | tynda
# Processing Record 10 of Set 9 | bud
# Processing Record 11 of Set 9 | ahuimanu
# Processing Record 12 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 9 | yerbogachen
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | nagorsk
# Processing Record 16 of Set 9 | nanortalik
# Processing Record 17 of Set 9 | tsagan aman
# Processing Record 18 of Set 9 | iquique
# Processing Record 19 of Set 9 | oksfjord
# Processing Record 20 of Set 9 | muzhi
# Processing Record 21 of Set 9 | swan hill
# Processing Record 22 of Set 9 | furth im wald
# Processing Record 23 of Set 9 | sur
# Processing Record 24 of Set 9 | svetlogorsk
# Processing Record 25 of Set 9 | sao felix do xingu
# Processing Record 26 of Set 9 | loiza
# Processing Record 27 of Set 9 | flinders
# Processing Record 28 of Set 9 | kamuli
# Processing Record 29 of Set 9 | batalha
# Processing Record 30 of Set 9 | sechura
# Processing Record 31 of Set 9 | yulara
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | eyl
# Processing Record 36 of Set 9 | belyy yar
# Processing Record 37 of Set 9 | taltal
# Processing Record 38 of Set 9 | sri aman
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | shahapur
# Processing Record 41 of Set 9 | champerico
# Processing Record 42 of Set 9 | risor
# Processing Record 43 of Set 9 | kargasok
# Processing Record 44 of Set 9 | nelson bay
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | mattru
# Processing Record 47 of Set 9 | sinnamary
# Processing Record 48 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 49 of Set 9 | honghu
# Processing Record 50 of Set 9 | breda
# Processing Record 1 of Set 10 | sabla
# Processing Record 2 of Set 10 | yaan
# Processing Record 3 of Set 10 | alofi
# Processing Record 4 of Set 10 | rongcheng
# Processing Record 5 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 10 | lompoc
# Processing Record 7 of Set 10 | nanakuli
# Processing Record 8 of Set 10 | nador
# Processing Record 9 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 10 | aklavik
# Processing Record 11 of Set 10 | ouadda
# Processing Record 12 of Set 10 | poso
# Processing Record 13 of Set 10 | minot
# Processing Record 14 of Set 10 | pokrovsk
# Processing Record 15 of Set 10 | qingdao
# Processing Record 16 of Set 10 | kuching
# Processing Record 17 of Set 10 | mehamn
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | san luis
# Processing Record 20 of Set 10 | dabakala
# Processing Record 21 of Set 10 | emerald
# Processing Record 22 of Set 10 | jalu
# Processing Record 23 of Set 10 | codrington
# Processing Record 24 of Set 10 | aberdeen
# Processing Record 25 of Set 10 | burnie
# Processing Record 26 of Set 10 | poum
# Processing Record 27 of Set 10 | nacala
# Processing Record 28 of Set 10 | hearst
# Processing Record 29 of Set 10 | leh
# Processing Record 30 of Set 10 | port augusta
# Processing Record 31 of Set 10 | urumqi
# Processing Record 32 of Set 10 | dianopolis
# City not found. Skipping...
# Processing Record 33 of Set 10 | norsup
# Processing Record 34 of Set 10 | chik
# Processing Record 35 of Set 10 | tacoronte
# Processing Record 36 of Set 10 | oktyabrskiy
# Processing Record 37 of Set 10 | beni mazar
# Processing Record 38 of Set 10 | solwezi
# Processing Record 39 of Set 10 | klaksvik
# Processing Record 40 of Set 10 | aasiaat
# Processing Record 41 of Set 10 | bambous virieux
# Processing Record 42 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 10 | portland
# Processing Record 44 of Set 10 | beringovskiy
# Processing Record 45 of Set 10 | valley city
# Processing Record 46 of Set 10 | baruun-urt
# Processing Record 47 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | betare oya
# Processing Record 50 of Set 10 | san patricio
# Processing Record 1 of Set 11 | kahului
# Processing Record 2 of Set 11 | shelburne
# Processing Record 3 of Set 11 | nokaneng
# Processing Record 4 of Set 11 | abnub
# Processing Record 5 of Set 11 | clearwater
# Processing Record 6 of Set 11 | kortkeros
# Processing Record 7 of Set 11 | alice springs
# Processing Record 8 of Set 11 | werota
# Processing Record 9 of Set 11 | pietermaritzburg
# Processing Record 10 of Set 11 | ulladulla
# Processing Record 11 of Set 11 | dickinson
# Processing Record 12 of Set 11 | sal rei
# Processing Record 13 of Set 11 | tazovskiy
# Processing Record 14 of Set 11 | knoxville
# Processing Record 15 of Set 11 | silifke
# Processing Record 16 of Set 11 | chase
# Processing Record 17 of Set 11 | kotelnich
# Processing Record 18 of Set 11 | rangapara
# Processing Record 19 of Set 11 | eureka
# Processing Record 20 of Set 11 | vieques
# Processing Record 21 of Set 11 | west bay
# Processing Record 22 of Set 11 | inhumas
# Processing Record 23 of Set 11 | matara
# Processing Record 24 of Set 11 | okhotsk
# Processing Record 25 of Set 11 | angra
# City not found. Skipping...
# Processing Record 26 of Set 11 | thinadhoo
# Processing Record 27 of Set 11 | san jose
# Processing Record 28 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 11 | marystown
# Processing Record 30 of Set 11 | santa maria do para
# Processing Record 31 of Set 11 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 11 | kuang
# Processing Record 33 of Set 11 | posadas
# Processing Record 34 of Set 11 | luena
# Processing Record 35 of Set 11 | srivardhan
# Processing Record 36 of Set 11 | gerede
# Processing Record 37 of Set 11 | vardo
# Processing Record 38 of Set 11 | tarauaca
# Processing Record 39 of Set 11 | bereda
# Processing Record 40 of Set 11 | xuanzhou
# Processing Record 41 of Set 11 | nome
# Processing Record 42 of Set 11 | mutoko
# Processing Record 43 of Set 11 | malartic
# Processing Record 44 of Set 11 | broome
# Processing Record 45 of Set 11 | kedougou
# Processing Record 46 of Set 11 | sao jose da coroa grande
# Processing Record 47 of Set 11 | mo i rana
# Processing Record 48 of Set 11 | bantry
# Processing Record 49 of Set 11 | praia da vitoria
# Processing Record 50 of Set 11 | malanje
# Processing Record 1 of Set 12 | dutlwe
# Processing Record 2 of Set 12 | mildura
# Processing Record 3 of Set 12 | lake havasu city
# Processing Record 4 of Set 12 | kotdwara
# Processing Record 5 of Set 12 | nemuro
# Processing Record 6 of Set 12 | dolores
# Processing Record 7 of Set 12 | vestmannaeyjar
# Processing Record 8 of Set 12 | tamalin
# Processing Record 9 of Set 12 | villa bruzual
# Processing Record 10 of Set 12 | surbo
# Processing Record 11 of Set 12 | mastic beach
# Processing Record 12 of Set 12 | iskateley
# Processing Record 13 of Set 12 | kendari
# Processing Record 14 of Set 12 | tampakan
# Processing Record 15 of Set 12 | sann
# Processing Record 16 of Set 12 | fukue
# Processing Record 17 of Set 12 | buraydah
# Processing Record 18 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 19 of Set 12 | marsa matruh
# Processing Record 20 of Set 12 | henties bay
# Processing Record 21 of Set 12 | verkhniy baskunchak
# Processing Record 22 of Set 12 | pacific grove
# Processing Record 23 of Set 12 | bandarbeyla
# Processing Record 24 of Set 12 | payo
# Processing Record 25 of Set 12 | palestine
# Processing Record 26 of Set 12 | nandi
# Processing Record 27 of Set 12 | blagodatnoye
# Processing Record 28 of Set 12 | pingdingshan
# Processing Record 29 of Set 12 | atherton
# Processing Record 30 of Set 12 | saint-joseph
# Processing Record 31 of Set 12 | nishihara
# Processing Record 32 of Set 12 | stephenville
# Processing Record 33 of Set 12 | inuvik
# Processing Record 34 of Set 12 | zhuanghe
# Processing Record 35 of Set 12 | puerto escondido
# Processing Record 36 of Set 12 | lannion
# Processing Record 37 of Set 12 | wad madani
# Processing Record 38 of Set 12 | kitimat
# Processing Record 39 of Set 12 | severodvinsk
# Processing Record 40 of Set 12 | mitchell
# Processing Record 41 of Set 12 | santa cruz de la palma
# Processing Record 42 of Set 12 | puerto baquerizo moreno
# Processing Record 43 of Set 12 | kupino
# Processing Record 44 of Set 12 | boldog
# Processing Record 45 of Set 12 | general bravo
# Processing Record 46 of Set 12 | cururupu
# Processing Record 47 of Set 12 | nancha
# Processing Record 48 of Set 12 | suntar
# Processing Record 49 of Set 12 | ravenna
# Processing Record 50 of Set 12 | san eugenio
# Processing Record 1 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | ust-kuyga
# Processing Record 4 of Set 13 | maloy
# Processing Record 5 of Set 13 | baghdad
# Processing Record 6 of Set 13 | phaltan
# Processing Record 7 of Set 13 | druzhba
# Processing Record 8 of Set 13 | rio gallegos
# Processing Record 9 of Set 13 | spring valley
# Processing Record 10 of Set 13 | liling
# Processing Record 11 of Set 13 | aksu
# Processing Record 12 of Set 13 | troyes
# Processing Record 13 of Set 13 | pudozh
# Processing Record 14 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 13 | birjand
# Processing Record 16 of Set 13 | taksimo
# Processing Record 17 of Set 13 | athabasca
# Processing Record 18 of Set 13 | banda aceh
# Processing Record 19 of Set 13 | lowicz
# Processing Record 20 of Set 13 | hualmay
# Processing Record 21 of Set 13 | noumea
# Processing Record 22 of Set 13 | banff
# Processing Record 23 of Set 13 | iglesias
# Processing Record 24 of Set 13 | uige
# Processing Record 25 of Set 13 | esmeraldas
# Processing Record 26 of Set 13 | carutapera
# Processing Record 27 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 28 of Set 13 | ellensburg
# Processing Record 29 of Set 13 | calatagan
# Processing Record 30 of Set 13 | bathsheba
# Processing Record 31 of Set 13 | mooi river
# City not found. Skipping...
# Processing Record 32 of Set 13 | ust-tsilma
# Processing Record 33 of Set 13 | cumra
# Processing Record 34 of Set 13 | agara
# Processing Record 35 of Set 13 | samarai
# Processing Record 36 of Set 13 | makkaveyevo
# Processing Record 37 of Set 13 | caravelas
# Processing Record 38 of Set 13 | zhezkazgan
# Processing Record 39 of Set 13 | arman
# Processing Record 40 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 41 of Set 13 | afanasyevo
# City not found. Skipping...
# Processing Record 42 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 13 | nouadhibou
# Processing Record 44 of Set 13 | manicore
# Processing Record 45 of Set 13 | faya
# Processing Record 46 of Set 13 | dunedin
# Processing Record 47 of Set 13 | san andres
# Processing Record 48 of Set 13 | novyy urengoy
# Processing Record 49 of Set 13 | bossembele
# City not found. Skipping...
# Processing Record 50 of Set 13 | bulaevo
# Processing Record 1 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 2 of Set 14 | auki
# Processing Record 3 of Set 14 | korem
# Processing Record 4 of Set 14 | fecamp
# Processing Record 5 of Set 14 | monrovia
# Processing Record 6 of Set 14 | sacama
# Processing Record 7 of Set 14 | boa vista
# Processing Record 8 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 14 | jhelum
# Processing Record 10 of Set 14 | atyrau
# Processing Record 11 of Set 14 | huilong
# Processing Record 12 of Set 14 | bilma
# Processing Record 13 of Set 14 | port macquarie
# Processing Record 14 of Set 14 | diego de almagro
# Processing Record 15 of Set 14 | pitea
# Processing Record 16 of Set 14 | kaduna
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | kyshtovka
# Processing Record 19 of Set 14 | mendeleyevsk
# Processing Record 20 of Set 14 | chaozhou
# Processing Record 21 of Set 14 | soldotna
# Processing Record 22 of Set 14 | paterno
# Processing Record 23 of Set 14 | fort dodge
# Processing Record 24 of Set 14 | oranjemund
# Processing Record 25 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 26 of Set 14 | formosa
# Processing Record 27 of Set 14 | touros
# Processing Record 28 of Set 14 | batagay
# Processing Record 29 of Set 14 | winkler
# Processing Record 30 of Set 14 | chicama
# Processing Record 31 of Set 14 | lerwick
# Processing Record 32 of Set 14 | adre
# Processing Record 33 of Set 14 | wanning
# Processing Record 34 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 35 of Set 14 | isangel
# Processing Record 36 of Set 14 | greytown
# Processing Record 37 of Set 14 | esil
# Processing Record 38 of Set 14 | jumla
# Processing Record 39 of Set 14 | abalak
# Processing Record 40 of Set 14 | krasnogvardeyskoye
# Processing Record 41 of Set 14 | saint-denis
# Processing Record 42 of Set 14 | ulaangom
# Processing Record 43 of Set 14 | itaituba
# Processing Record 44 of Set 14 | iisaku
# Processing Record 45 of Set 14 | pipri
# Processing Record 46 of Set 14 | quatre cocos
# Processing Record 47 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 14 | sibolga
# Processing Record 49 of Set 14 | fontenay-le-comte
# Processing Record 50 of Set 14 | arrecife
# Processing Record 1 of Set 15 | mount isa
# Processing Record 2 of Set 15 | dembi dolo
# Processing Record 3 of Set 15 | maraba
# Processing Record 4 of Set 15 | kars
# Processing Record 5 of Set 15 | orapa
# Processing Record 6 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 15 | hasaki
# Processing Record 8 of Set 15 | frolovo
# Processing Record 9 of Set 15 | amapa
# Processing Record 10 of Set 15 | san joaquin
# Processing Record 11 of Set 15 | korla
# Processing Record 12 of Set 15 | lock haven
# Processing Record 13 of Set 15 | perpignan
# Processing Record 14 of Set 15 | doha
# Processing Record 15 of Set 15 | zaysan
# Processing Record 16 of Set 15 | mandera
# Processing Record 17 of Set 15 | ishinomaki
# Processing Record 18 of Set 15 | songadh
# Processing Record 19 of Set 15 | prabumulih
# Processing Record 20 of Set 15 | katangli
# Processing Record 21 of Set 15 | palmer
# Processing Record 22 of Set 15 | wad rawah
# Processing Record 23 of Set 15 | narwana
# Processing Record 24 of Set 15 | mezen
# Processing Record 25 of Set 15 | umm kaddadah
# Processing Record 26 of Set 15 | bara
# Processing Record 27 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 15 | araouane
# Processing Record 29 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 15 | rabo de peixe
# Processing Record 31 of Set 15 | zolotonosha
# Processing Record 32 of Set 15 | spearfish
# Processing Record 33 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 15 | dawlatabad
# Processing Record 35 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 15 | valparaiso
# Processing Record 37 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 38 of Set 15 | jiroft
# City not found. Skipping...
# Processing Record 39 of Set 15 | chengde
# Processing Record 40 of Set 15 | oriximina
# Processing Record 41 of Set 15 | egvekinot
# Processing Record 42 of Set 15 | osypenko
# Processing Record 43 of Set 15 | rognan
# Processing Record 44 of Set 15 | buin
# Processing Record 45 of Set 15 | stokmarknes
# Processing Record 46 of Set 15 | soyo
# Processing Record 47 of Set 15 | yizheng
# Processing Record 48 of Set 15 | fare
# Processing Record 49 of Set 15 | banon
# Processing Record 50 of Set 15 | pitimbu
# Processing Record 1 of Set 16 | asfi
# Processing Record 2 of Set 16 | olutanga
# Processing Record 3 of Set 16 | bolkhov
# Processing Record 4 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 16 | axim
# Processing Record 6 of Set 16 | great yarmouth
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(5)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kabalo  -6.0500   26.9167     69.84        95         100
# 1       Rikitea -23.1203 -134.9692     77.02        72         100
# 2        Marawi   7.9986  124.2928     71.65        88          94
# 3  Punta Arenas -53.1500  -70.9167     51.91        50           0
# 4      Havelock  34.8791  -76.9013     33.78        56           0
#
#    Wind Speed Country                 Date Current Description
# 0        1.25      CD  2022-01-30 00:16:20     overcast clouds
# 1        8.16      PF  2022-01-30 00:12:53     overcast clouds
# 2        1.19      PH  2022-01-30 00:16:20     overcast clouds
# 3        6.91      CL  2022-01-30 00:16:21           clear sky
# 4        5.01      US  2022-01-30 00:14:04           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.sample(5)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 23           Majene      ID  -3.5403  118.9707     79.84        75
# 487         Posadas      AR -27.3671  -55.8961     84.18        54
# 619          Touros      BR  -5.1989  -35.4608     77.90        82
# 260  Cap Malheureux      MU -19.9842   57.6142     79.29        78
# 407      Nelson Bay      AU -32.7167  152.1500     83.28        65
#
#      Cloudiness  Wind Speed Current Description
# 23          100        1.63     overcast clouds
# 487           0        5.75           clear sky
# 619          85        9.66     overcast clouds
# 260          92        1.99     overcast clouds
# 407          44        1.99    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
